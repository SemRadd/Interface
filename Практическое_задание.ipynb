# %% [markdown]
# <a href="https://colab.research.google.com/github/SemRadd/Interface/blob/master/%D0%9F%D1%80%D0%B0%D0%BA%D1%82%D0%B8%D1%87%D0%B5%D1%81%D0%BA%D0%BE%D0%B5_%D0%B7%D0%B0%D0%B4%D0%B0%D0%BD%D0%B8%D0%B5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sortedcontainers import SortedList
from future.utils import iteritems

# %%
from sklearn.datasets import make_moons
from sklearn.datasets import make_blobs

X, y = make_moons(n_samples=100, random_state=42)
# X, y = make_blobs(n_samples=10, centers=3, n_features=2, random_state=0)
plt.scatter(X[:,0], X[:,1], s=100, c=y, alpha=0.5)
plt.show()

# %%
X
# Out:
# array([[ 1.51839257e+00, -3.55142763e-01],
#        [ 1.84408430e-02,  3.08841371e-01],
#        [ 7.15472413e-01, -4.58667853e-01],
#        [-9.67294863e-01,  2.53654584e-01],
#        [-9.49055747e-01,  3.15108218e-01],
#        [-8.01413622e-01,  5.98110530e-01],
#        [ 1.59599895e-01,  9.87181783e-01],
#        [ 1.34536505e+00, -4.38468422e-01],
#        [ 8.01413622e-01,  5.98110530e-01],
#        [ 1.00000000e+00,  0.00000000e+00],
#        [ 4.04783343e-01,  9.14412623e-01],
#        [-3.45365054e-01,  9.38468422e-01],
#        [ 9.03976974e-01, -4.95379113e-01],
#        [-5.18392568e-01,  8.55142763e-01],
#        [ 1.83808810e+00, -4.55349012e-02],
#        [ 9.67294863e-01,  2.53654584e-01],
#        [ 1.09602303e+00, -4.95379113e-01],
#        [ 1.15959990e+00, -4.87181783e-01],
#        [ 7.18349350e-01,  6.95682551e-01],
#        [-4.04783343e-01,  9.14412623e-01],
#        [ 5.09442530e-02,  1.84891782e-01],
#        [ 1.76144596e+00, -1.48228395e-01],
# ...
